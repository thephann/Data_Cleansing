# %%
import numpy as np 
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline



pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Loading data

# %%
fifa21_data = pd.read_csv('../input/fifa-21-complete-player-dataset/fifa21_male2.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fifa21_data.head(5)
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                           Club Logo  \
# 0      https://cdn.sofifa.com/teams/55/light_60.png
# 1    https://cdn.sofifa.com/teams/2013/light_60.png
# 2    https://cdn.sofifa.com/teams/1800/light_60.png
# 3     https://cdn.sofifa.com/teams/106/light_60.png
# 4  https://cdn.sofifa.com/teams/101146/light_60.png
#
#                                 Flag Photo  POT            Team & Contract  \
# 0      https://cdn.sofifa.com/flags/it.png   69        Udinese 2008 ~ 2016
# 1      https://cdn.sofifa.com/flags/es.png   71      KAS Eupen 2014 ~ 2019
# 2  https://cdn.sofifa.com/flags/gb-eng.png   71  Coventry City 2016 ~ 2020
# 3      https://cdn.sofifa.com/flags/tt.png   82            Sunderland 2009
# 4      https://cdn.sofifa.com/flags/es.png   81    Vissel Kobe 2018 ~ 2021
#
#   Height  Weight   foot  Growth        Joined Loan Date End  Value  Wage  \
# 0   6'0"  181lbs   Left       0   Jul 1, 2008           NaN  €625K   €7K
# 1  5'10"  143lbs  Right       0  Jul 19, 2014           NaN  €600K   €7K
# 2   5'9"  161lbs  Right       0   Jan 7, 2016           NaN  €1.1M  €15K
# 3  5'11"  165lbs  Right      14           NaN           NaN     €0    €0
# 4   5'7"  150lbs  Right       0  Jul 16, 2018           NaN  €5.5M  €12K
#
#   Release Clause     Contract  Attacking  Crossing  Finishing  \
# 0             €0  2008 ~ 2016        313        75         50
# 1          €1.1M  2014 ~ 2019        337        68         64
# 2             €0  2016 ~ 2020        337        80         64
# 3             €0         2009        264        54         70
# 4          €7.2M  2018 ~ 2021        367        75         69
#
#    Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# 0                59             71     58.0    338         73   65.0
# 1                61             76     68.0    369         69   79.0
# 2                41             77     75.0    387         79   84.0
# 3                60             80      NaN    255         68    NaN
# 4                54             90     79.0    408         85   80.0
#
#    FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# 0           60            69            71       347            68
# 1           79            71            71       305            56
# 2           77            69            78       295            48
# 3           46            64            77       176            59
# 4           70            83            90       346            61
#
#    Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  Jumping  \
# 0            74     68.0         69     68.0    347          74     68.0
# 1            50     62.0         65     72.0    324          75     54.0
# 2            42     71.0         59     75.0    284          72     58.0
# 3            62      NaN         55      NaN    239          63      NaN
# 4            56     79.0         75     75.0    297          67     40.0
#
#    Stamina  Strength  Long Shots  Mentality  Aggression  Interceptions  \
# 0       69        68          68        320          72           69.0
# 1       64        60          71        362          71           71.0
# 2       29        56          69        317          69           39.0
# 3       51        66          59        271          59           70.0
# 4       58        62          70        370          58           70.0
#
#    Positioning  Vision  Penalties  Composure  Defending  Marking  \
# 0         63.0    66.0         50        NaN        208       70
# 1         72.0    73.0         75       79.0        153       70
# 2         69.0    74.0         66        NaN         99       35
# 3         72.0     NaN         70        NaN         75       34
# 4         78.0    93.0         71       89.0        181       68
#
#    Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  GK Handling  \
# 0               69            69.0           56         14            5
# 1               43            40.0           56          9           12
# 2               34            30.0           51          9            6
# 3               41             NaN           68          5           21
# 4               57            56.0           45          6           13
#
#    GK Kicking  GK Positioning  GK Reflexes  Total Stats  Base Stats  W/F  SM  \
# 0          15              10           12         1929         408  3 ★  2★
# 1          13              11           11         1906         385  4 ★  3★
# 2          13              16            7         1770         354  4 ★  4★
# 3          64              21           21         1348         369  3 ★  1★
# 4           6              13            7         2014         420  4 ★  4★
#
#       A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS  \
# 0  Medium    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0
# 1  Medium  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1
# 2  Medium     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0
# 3     NaN     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0
# 4    High  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3
#
#      LW    LF    CF    RF    RW    LAM    CAM    RAM    LM   LCM    CM   RCM  \
# 0  68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0  69+0  69+0  69+0
# 1  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1  70+1  70+1  70+1
# 2  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0  66+0  66+0  66+0
# 3  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0  68+0  68+0  68+0
# 4  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2  81+0  81+0  81+0
#
#      RM    LWB    LDM    CDM    RDM    RWB     LB   LCB    CB   RCB     RB  \
# 0  69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1
# 1  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1
# 2  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0
# 3  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0
# 4  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3
#
#      GK Gender
# 0  17+0   Male
# 1  17+1   Male
# 2  15+0   Male
# 3  22+0   Male
# 4  17+3   Male

# %%
fifa21_data.shape
# Out:
# (17125, 107)

# %% [markdown]
# # Remove the columns

# %%
fifa21_data.drop(['ID','Player Photo', 'Club Logo', 'Flag Photo', 'Joined', 'Loan Date End', 'Team & Contract', 'Contract', 'W/F', 'SM', 'IR', 'Gender', 'Position'], axis=1, inplace=True)

# %%
fifa21_data.shape
# Out:
# (17125, 94)

# %% [markdown]
# # Data cleansing

# %%
fifa21_data.isnull().sum()
# Out:
# Name                  0
# Age                   0
# OVA                   0
# Nationality           0
# Club                 23
# BOV                   0
# BP                    0
# POT                   0
# Height                0
# Weight                0
# foot                  0
# Growth                0
# Value                 0
# Wage                  0
# Release Clause        0
# Attacking             0
# Crossing              0
# Finishing             0
# Heading Accuracy      0
# Short Passing         0
# Volleys              58
# Skill                 0
# Dribbling             0
# Curve                58
# FK Accuracy           0
# Long Passing          0
# Ball Control          0
# Movement              0
# Acceleration          0
# Sprint Speed          0
# Agility              58
# Reactions             0
# Balance              58
# Power                 0
# Shot Power            0
# Jumping              58
# Stamina               0
# Strength              0
# Long Shots            0
# Mentality             0
# Aggression            0
# Interceptions         7
# Positioning           7
# Vision               58
# Penalties             0
# Composure           423
# Defending             0
# Marking               0
# Standing Tackle       0
# Sliding Tackle       58
# Goalkeeping           0
# GK Diving             0
# GK Handling           0
# GK Kicking            0
# GK Positioning        0
# GK Reflexes           0
# Total Stats           0
# Base Stats            0
# A/W                  89
# D/W                  89
# PAC                   0
# SHO                   0
# PAS                   0
# DRI                   0
# DEF                   0
# PHY                   0
# Hits                  0
# LS                    0
# ST                    0
# RS                    0
# LW                    0
# LF                    0
# CF                    0
# RF                    0
# RW                    0
# LAM                   0
# CAM                   0
# RAM                   0
# LM                    0
# LCM                   0
# CM                    0
# RCM                   0
# RM                    0
# LWB                   0
# LDM                   0
# CDM                   0
# RDM                   0
# RWB                   0
# LB                    0
# LCB                   0
# CB                    0
# RCB                   0
# RB                    0
# GK                    0
# dtype: int64

# %%
fifa21_data['Volleys'].fillna(fifa21_data['Volleys'].mean(), inplace = True) 
fifa21_data['Curve'].fillna(fifa21_data['Curve'].mean(), inplace = True)
fifa21_data['Agility'].fillna(fifa21_data['Agility'].mean(), inplace = True)
fifa21_data['Balance'].fillna(fifa21_data['Balance'].mean(), inplace = True)
fifa21_data['Jumping'].fillna(fifa21_data['Jumping'].mean(), inplace = True)
fifa21_data['Interceptions'].fillna(fifa21_data['Interceptions'].mean(), inplace = True)
fifa21_data['Positioning'].fillna(fifa21_data['Positioning'].mean(), inplace = True)
fifa21_data['Composure'].fillna(fifa21_data['Composure'].mean(), inplace = True)
fifa21_data['Sliding Tackle'].fillna(fifa21_data['Sliding Tackle'].mean(), inplace = True) 
fifa21_data['Vision'].fillna(fifa21_data['Vision'].mean(), inplace = True)

# %%
fifa21_data['Wage'].head(5)
# Out:
# 0     €7K
# 1     €7K
# 2    €15K
# 3      €0
# 4    €12K
# Name: Wage, dtype: object

# %%
fifa21_data['Value'].head(5)
# Out:
# 0    €625K
# 1    €600K
# 2    €1.1M
# 3       €0
# 4    €5.5M
# Name: Value, dtype: object

# %%
def value_handling(Value):
    if isinstance(Value,str):
        out = Value.replace('€', '')
        if 'M' in out:
            out = float(out.replace('M', ''))*1000000
        elif 'K' in Value:
            out = float(out.replace('K', ''))*1000
        return float(out)

# %%
fifa21_data['Value'] = fifa21_data['Value'].apply(lambda x: value_handling(x))
fifa21_data['Release Clause'] = fifa21_data['Release Clause'].apply(lambda x: value_handling(x))
fifa21_data['Release Clause'].fillna(fifa21_data['Release Clause'].mean(), inplace = True)

# %%
fifa21_data.head(5)
# Out:
#           Name  Age  OVA            Nationality           Club  BOV   BP  POT  \
# 0  G. Pasquale   33   69                  Italy        Udinese   71  LWB   69
# 1  Luis García   37   71                  Spain      KAS Eupen   70   CM   71
# 2      J. Cole   33   71                England  Coventry City   71  CAM   71
# 3     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST   82
# 4      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM   81
#
#   Height  Weight   foot  Growth      Value  Wage  Release Clause  Attacking  \
# 0   6'0"  181lbs   Left       0   625000.0   €7K             0.0        313
# 1  5'10"  143lbs  Right       0   600000.0   €7K       1100000.0        337
# 2   5'9"  161lbs  Right       0  1100000.0  €15K             0.0        337
# 3  5'11"  165lbs  Right      14        0.0    €0             0.0        264
# 4   5'7"  150lbs  Right       0  5500000.0  €12K       7200000.0        367
#
#    Crossing  Finishing  Heading Accuracy  Short Passing    Volleys  Skill  \
# 0        75         50                59             71  58.000000    338
# 1        68         64                61             76  68.000000    369
# 2        80         64                41             77  75.000000    387
# 3        54         70                60             80  45.005742    255
# 4        75         69                54             90  79.000000    408
#
#    Dribbling      Curve  FK Accuracy  Long Passing  Ball Control  Movement  \
# 0         73  65.000000           60            69            71       347
# 1         69  79.000000           79            71            71       305
# 2         79  84.000000           77            69            78       295
# 3         68  49.574676           46            64            77       176
# 4         85  80.000000           70            83            90       346
#
#    Acceleration  Sprint Speed    Agility  Reactions    Balance  Power  \
# 0            68            74  68.000000         69  68.000000    347
# 1            56            50  62.000000         65  72.000000    324
# 2            48            42  71.000000         59  75.000000    284
# 3            59            62  64.602273         55  64.715591    239
# 4            61            56  79.000000         75  75.000000    297
#
#    Shot Power    Jumping  Stamina  Strength  Long Shots  Mentality  \
# 0          74  68.000000       69        68          68        320
# 1          75  54.000000       64        60          71        362
# 2          72  58.000000       29        56          69        317
# 3          63  65.170212       51        66          59        271
# 4          67  40.000000       58        62          70        370
#
#    Aggression  Interceptions  Positioning     Vision  Penalties  Composure  \
# 0          72           69.0         63.0  66.000000         50  59.940965
# 1          71           71.0         72.0  73.000000         75  79.000000
# 2          69           39.0         69.0  74.000000         66  59.940965
# 3          59           70.0         72.0  55.443605         70  59.940965
# 4          58           70.0         78.0  93.000000         71  89.000000
#
#    Defending  Marking  Standing Tackle  Sliding Tackle  Goalkeeping  \
# 0        208       70               69       69.000000           56
# 1        153       70               43       40.000000           56
# 2         99       35               34       30.000000           51
# 3         75       34               41       46.099725           68
# 4        181       68               57       56.000000           45
#
#    GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0         14            5          15              10           12
# 1          9           12          13              11           11
# 2          9            6          13              16            7
# 3          5           21          64              21           21
# 4          6           13           6              13            7
#
#    Total Stats  Base Stats     A/W     D/W  PAC  SHO  PAS  DRI  DEF  PHY Hits  \
# 0         1929         408  Medium    High   71   59   70   71   68   69    4
# 1         1906         385  Medium  Medium   53   69   73   69   58   63    4
# 2         1770         354  Medium     Low   45   68   76   77   36   52   11
# 3         1348         369     NaN     NaN   61   66   66   69   47   60    3
# 4         2014         420    High  Medium   58   70   85   85   63   59  149
#
#      LS    ST    RS    LW    LF    CF    RF    RW    LAM    CAM    RAM    LM  \
# 0  65+0  65+0  65+0  68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0
# 1  67+1  67+1  67+1  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1
# 2  64+0  64+0  64+0  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0
# 3  67+0  67+0  67+0  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0
# 4  72+3  72+3  72+3  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2
#
#     LCM    CM   RCM    RM    LWB    LDM    CDM    RDM    RWB     LB   LCB  \
# 0  69+0  69+0  69+0  69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0
# 1  70+1  70+1  70+1  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1
# 2  66+0  66+0  66+0  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0
# 3  68+0  68+0  68+0  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0
# 4  81+0  81+0  81+0  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3
#
#      CB   RCB     RB    GK
# 0  69+0  69+0  70+-1  17+0
# 1  60+1  60+1   60+1  17+1
# 2  46+0  46+0   47+0  15+0
# 3  51+0  51+0   57+0  22+0
# 4  64+3  64+3   67+3  17+3

# %%
def wage_handling(value):
    out = value.replace('€', '')
    if 'K' in out:
        out = float(out.replace('K', ''))*1000
    else:
        out = out
    return float(out)

fifa21_data['Wage'] = fifa21_data['Wage'].apply(lambda x: wage_handling(x))
fifa21_data.Wage.head(3)
# Out:
# 0     7000.0
# 1     7000.0
# 2    15000.0
# Name: Wage, dtype: float64

# %%
# Height columns
fifa21_data.Height.head(3)
# Out:
# 0     6'0"
# 1    5'10"
# 2     5'9"
# Name: Height, dtype: object

# %%
def feet_to_cm(value):
    h_inch = int(value.split("'")[1][:-1])
    h_inch += int(value.split("'")[0]) * 12
    h_cm = round(h_inch * 2.54, 1)
    return h_cm

fifa21_data['Height'] = fifa21_data['Height'].apply(lambda x: feet_to_cm(x))
fifa21_data['Height'].fillna((fifa21_data['Height'].mean()), inplace = True)
fifa21_data.Height.head(5)
# Out:
# 0    182.9
# 1    177.8
# 2    175.3
# 3    180.3
# 4    170.2
# Name: Height, dtype: float64

# %%
# Weight columns
def lbs_to_kg(x):
    out = float(x.replace('lbs', ''))
    kgs = out/2.2046
    out = round(kgs , 2)
    return float(out)

fifa21_data['Weight'] = fifa21_data['Weight'].apply(lambda x: lbs_to_kg(x))
fifa21_data['Weight'].fillna((fifa21_data['Weight'].mean()), inplace = True)
fifa21_data.Weight.head(5)
# Out:
# 0    82.10
# 1    64.86
# 2    73.03
# 3    74.84
# 4    68.04
# Name: Weight, dtype: float64

# %%
#Categorical Columns
fifa21_data['Club'].fillna('No Club', inplace = True)

# %%
fifa21_data['A/W'].value_counts()
# Out:
# Medium    11044
# High       5143
# Low         849
# Name: A/W, dtype: int64

# %%
fifa21_data['A/W'].fillna('Medium', inplace = True)

# %%
fifa21_data['D/W'].value_counts()
# Out:
# Medium    12225
# High       3017
# Low        1794
# Name: D/W, dtype: int64

# %%
fifa21_data['D/W'].fillna('Medium', inplace = True)

# %%
fifa21_data.head(3)
# Out:
#           Name  Age  OVA Nationality           Club  BOV   BP  POT  Height  \
# 0  G. Pasquale   33   69       Italy        Udinese   71  LWB   69   182.9
# 1  Luis García   37   71       Spain      KAS Eupen   70   CM   71   177.8
# 2      J. Cole   33   71     England  Coventry City   71  CAM   71   175.3
#
#    Weight   foot  Growth      Value     Wage  Release Clause  Attacking  \
# 0   82.10   Left       0   625000.0   7000.0             0.0        313
# 1   64.86  Right       0   600000.0   7000.0       1100000.0        337
# 2   73.03  Right       0  1100000.0  15000.0             0.0        337
#
#    Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  Skill  \
# 0        75         50                59             71     58.0    338
# 1        68         64                61             76     68.0    369
# 2        80         64                41             77     75.0    387
#
#    Dribbling  Curve  FK Accuracy  Long Passing  Ball Control  Movement  \
# 0         73   65.0           60            69            71       347
# 1         69   79.0           79            71            71       305
# 2         79   84.0           77            69            78       295
#
#    Acceleration  Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  \
# 0            68            74     68.0         69     68.0    347          74
# 1            56            50     62.0         65     72.0    324          75
# 2            48            42     71.0         59     75.0    284          72
#
#    Jumping  Stamina  Strength  Long Shots  Mentality  Aggression  \
# 0     68.0       69        68          68        320          72
# 1     54.0       64        60          71        362          71
# 2     58.0       29        56          69        317          69
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Defending  \
# 0           69.0         63.0    66.0         50  59.940965        208
# 1           71.0         72.0    73.0         75  79.000000        153
# 2           39.0         69.0    74.0         66  59.940965         99
#
#    Marking  Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  \
# 0       70               69            69.0           56         14
# 1       70               43            40.0           56          9
# 2       35               34            30.0           51          9
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes  Total Stats  \
# 0            5          15              10           12         1929
# 1           12          13              11           11         1906
# 2            6          13              16            7         1770
#
#    Base Stats     A/W     D/W  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST  \
# 0         408  Medium    High   71   59   70   71   68   69    4  65+0  65+0
# 1         385  Medium  Medium   53   69   73   69   58   63    4  67+1  67+1
# 2         354  Medium     Low   45   68   76   77   36   52   11  64+0  64+0
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  65+0  68+0  67+0  67+0  67+0  68+0  68+0  68+0  68+0  69+0  69+0  69+0
# 1  67+1  67+0  68+0  68+0  68+0  67+0  70+1  70+1  70+1  68+1  70+1  70+1
# 2  64+0  70+0  69+0  69+0  69+0  70+0  71+0  71+0  71+0  68+0  66+0  66+0
#
#     RCM    RM    LWB    LDM    CDM    RDM    RWB     LB   LCB    CB   RCB  \
# 0  69+0  69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0
# 1  70+1  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1
# 2  66+0  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0
#
#       RB    GK
# 0  70+-1  17+0
# 1   60+1  17+1
# 2   47+0  15+0

# %%
def skill_rating(value):
    if isinstance(value,str):
        s = int(value[0:2]) + int(value[-1])
        return s
    else:
        return value

# %%
skill_columns = ['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM',
       'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM',
       'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

for col in skill_columns:
    fifa21_data[col] = fifa21_data[col].apply(skill_rating)

# %%
def skill_rating_1(value):
    val_split = value.split('+')
    out = int(val_split[0]) + int(val_split[1])
    return out
    
fifa21_data['GK'] = fifa21_data['GK'].apply(skill_rating_1)

# %%
def foot_conversion(value):
    if (value == 'Right'):
        return 1
    else:
        return 0
    
fifa21_data['foot'] = fifa21_data['foot'].apply(foot_conversion)

# %%
fifa21_data['A/W'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
fifa21_data['D/W'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
AW_DW = {
    'High': 2,
    'Medium': 1,
    'Low': 0
}
fifa21_data['A/W'] = fifa21_data['A/W'].map(AW_DW)
fifa21_data['D/W'] = fifa21_data['D/W'].map(AW_DW)

# %%
fifa21_data.BP.unique()
# Out:
# array(['LWB', 'CM', 'CAM', 'ST', 'RW', 'CB', 'CF', 'GK', 'CDM', 'RWB',
#        'LB', 'LM', 'RM', 'RB', 'LW'], dtype=object)

# %%
def BP_conversion(value):
    if (value == 'GK'):
        return 'GK'
    elif ((value == 'LWB') | (value == 'CB') | (value == 'RWB') | (value == 'LB') | (value == 'RB')):
        return 'DF'
    elif ((value == 'CDM')):
        return 'DM'
    elif ((value == 'LM') | (value == 'CM') | (value == 'RM')):
        return 'MF'
    elif ((value == 'CAM')):
        return 'AM'
    elif ((value == 'RW') | (value == 'ST') | (value == 'LW') | (value == 'CF')):
        return 'ST'
    else:
        return value

fifa21_data['BP'] = fifa21_data['BP'].apply(BP_conversion)

# %%
BP_position = {
    'GK':0,
    'DF':1,
    'DM':2,
    'MF':3,
    'AM':4,
    'ST':5
}
fifa21_data['BP'] = fifa21_data['BP'].map(BP_position)

# %%
fifa21_data.head(5)
# Out:
#           Name  Age  OVA            Nationality           Club  BOV  BP  POT  \
# 0  G. Pasquale   33   69                  Italy        Udinese   71   1   69
# 1  Luis García   37   71                  Spain      KAS Eupen   70   3   71
# 2      J. Cole   33   71                England  Coventry City   71   4   71
# 3     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   5   82
# 4      Iniesta   36   81                  Spain    Vissel Kobe   82   4   81
#
#    Height  Weight  foot  Growth      Value     Wage  Release Clause  \
# 0   182.9   82.10     0       0   625000.0   7000.0             0.0
# 1   177.8   64.86     1       0   600000.0   7000.0       1100000.0
# 2   175.3   73.03     1       0  1100000.0  15000.0             0.0
# 3   180.3   74.84     1      14        0.0      0.0             0.0
# 4   170.2   68.04     1       0  5500000.0  12000.0       7200000.0
#
#    Attacking  Crossing  Finishing  Heading Accuracy  Short Passing    Volleys  \
# 0        313        75         50                59             71  58.000000
# 1        337        68         64                61             76  68.000000
# 2        337        80         64                41             77  75.000000
# 3        264        54         70                60             80  45.005742
# 4        367        75         69                54             90  79.000000
#
#    Skill  Dribbling      Curve  FK Accuracy  Long Passing  Ball Control  \
# 0    338         73  65.000000           60            69            71
# 1    369         69  79.000000           79            71            71
# 2    387         79  84.000000           77            69            78
# 3    255         68  49.574676           46            64            77
# 4    408         85  80.000000           70            83            90
#
#    Movement  Acceleration  Sprint Speed    Agility  Reactions    Balance  \
# 0       347            68            74  68.000000         69  68.000000
# 1       305            56            50  62.000000         65  72.000000
# 2       295            48            42  71.000000         59  75.000000
# 3       176            59            62  64.602273         55  64.715591
# 4       346            61            56  79.000000         75  75.000000
#
#    Power  Shot Power    Jumping  Stamina  Strength  Long Shots  Mentality  \
# 0    347          74  68.000000       69        68          68        320
# 1    324          75  54.000000       64        60          71        362
# 2    284          72  58.000000       29        56          69        317
# 3    239          63  65.170212       51        66          59        271
# 4    297          67  40.000000       58        62          70        370
#
#    Aggression  Interceptions  Positioning     Vision  Penalties  Composure  \
# 0          72           69.0         63.0  66.000000         50  59.940965
# 1          71           71.0         72.0  73.000000         75  79.000000
# 2          69           39.0         69.0  74.000000         66  59.940965
# 3          59           70.0         72.0  55.443605         70  59.940965
# 4          58           70.0         78.0  93.000000         71  89.000000
#
#    Defending  Marking  Standing Tackle  Sliding Tackle  Goalkeeping  \
# 0        208       70               69       69.000000           56
# 1        153       70               43       40.000000           56
# 2         99       35               34       30.000000           51
# 3         75       34               41       46.099725           68
# 4        181       68               57       56.000000           45
#
#    GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0         14            5          15              10           12
# 1          9           12          13              11           11
# 2          9            6          13              16            7
# 3          5           21          64              21           21
# 4          6           13           6              13            7
#
#    Total Stats  Base Stats  A/W  D/W  PAC  SHO  PAS  DRI  DEF  PHY Hits  LS  \
# 0         1929         408    1    2   71   59   70   71   68   69    4  65
# 1         1906         385    1    1   53   69   73   69   58   63    4  68
# 2         1770         354    1    0   45   68   76   77   36   52   11  64
# 3         1348         369    1    1   61   66   66   69   47   60    3  67
# 4         2014         420    2    1   58   70   85   85   63   59  149  75
#
#    ST  RS  LW  LF  CF  RF  RW  LAM  CAM  RAM  LM  LCM  CM  RCM  RM  LWB  LDM  \
# 0  65  65  68  67  67  67  68   68   68   68  69   69  69   69  69   73   71
# 1  68  68  67  68  68  68  67   71   71   71  69   71  71   71  69   63   67
# 2  64  64  70  69  69  69  70   71   71   71  68   66  66   66  68   52   54
# 3  67  67  66  67  67  67  66   70   70   70  66   68  68   68  66   56   65
# 4  75  75  79  79  79  79  79   83   83   83  81   81  81   81  81   73   76
#
#    CDM  RDM  RWB  LB  LCB  CB  RCB  RB  GK
# 0   71   71   73  71   69  69   69  71  17
# 1   67   67   63  61   61  61   61  61  18
# 2   54   54   52  47   46  46   46  47  15
# 3   65   65   56  57   51  51   51  57  22
# 4   76   76   73  70   67  67   67  70  20
